# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from pyod.models.knn import KNN

normal_path = "fouriers/S01/1/Normal/q_data"
relay_path  = "fouriers/S01/1/Relay/q_data"

with h5py.File("datasets/fouriers_S01_combined.h5", "r") as f:
    normal_group = f[normal_path]
    relay_group  = f[relay_path]

    dataset_normal = np.zeros((10916, 72))
    dataset_relay  = np.zeros((9239, 72))

    for i in range(10916):
        try:
            dataset_normal[i] = normal_group[str(i)][:]
        except KeyError:
            continue

    for i in range(9239):
        try:
            dataset_relay[i] = relay_group[str(i)][:]
        except KeyError:
            continue

scalerMinMax = MinMaxScaler()
scalerStandard = StandardScaler()

X_train               = dataset_normal[:9916]
X_test_normal         = dataset_normal[9916:]
X_test_relay          = dataset_relay[8239:]

scalerMinMax.fit(X_train)
X_train_scaled_minmax       = scalerMinMax.transform(X_train)
X_test_norm_scaled_minmax   = scalerMinMax.transform(X_test_normal)
X_test_relay_scaled_minmax  = scalerMinMax.transform(X_test_relay)

scalerStandard.fit(X_train)
X_train_scaled_standard        = scalerStandard.transform(X_train)
X_test_norm_scaled_standard    = scalerStandard.transform(X_test_normal)
X_test_relay_scaled_standard   = scalerStandard.transform(X_test_relay)

X_test_combined = np.vstack((X_test_normal, X_test_relay))
X_test_combined_scaled_minmax = np.vstack((X_test_norm_scaled_minmax, X_test_relay_scaled_minmax))
X_test_combined_scaled_standard = np.vstack((X_test_norm_scaled_standard, X_test_relay_scaled_standard))

y_true = np.array([0] * len(X_test_normal) + [1] * len(X_test_relay))

# %%
for n in {3,5,10,50}:
    for m in {"cityblock", "euclidean", "l1", "l2","manhattan"}:
        clf = KNN(contamination=0.01, n_neighbors=n, metric=m)
        clf.fit(X_train)

        # pyod.predict: 0 = inlier, 1 = outlier
        y_pred = clf.predict(X_test_combined)

        # cm und report
        cm = confusion_matrix(y_true, y_pred, labels=[1,0])
        print(f"n neighbors: {n}")
        print(f"metric: {m}")
        print("\nClassification Report:\n", classification_report(y_true, y_pred, target_names=["Normal","Relay"]))

        # plot
        plt.figure(figsize=(6,5))
        sns.heatmap(cm, annot=True, fmt="d",
                    xticklabels=["Relay","Normal"],
                    yticklabels=["Relay","Normal"],
                    cbar=False)
        plt.xlabel("Predicted")
        plt.ylabel("True")
        plt.title("Konfusionsmatrix")
        plt.tight_layout()
        plt.show()
# Out:
# n neighbors: 10
# metric: cityblock
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.52      0.99      0.68      1000
#        Relay       0.91      0.08      0.15      1000
#
#     accuracy                           0.54      2000
#    macro avg       0.72      0.54      0.42      2000
# weighted avg       0.72      0.54      0.42      2000
# n neighbors: 10
# metric: euclidean
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.52      0.99      0.68      1000
#        Relay       0.89      0.08      0.14      1000
#
#     accuracy                           0.53      2000
#    macro avg       0.70      0.53      0.41      2000
# weighted avg       0.70      0.53      0.41      2000
# n neighbors: 10
# metric: manhattan
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.52      0.99      0.68      1000
#        Relay       0.91      0.08      0.15      1000
#
#     accuracy                           0.54      2000
#    macro avg       0.72      0.54      0.42      2000
# weighted avg       0.72      0.54      0.42      2000
# n neighbors: 10
# metric: l2
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.52      0.99      0.68      1000
#        Relay       0.89      0.08      0.14      1000
#
#     accuracy                           0.53      2000
#    macro avg       0.70      0.53      0.41      2000
# weighted avg       0.70      0.53      0.41      2000
# n neighbors: 10
# metric: l1
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.52      0.99      0.68      1000
#        Relay       0.91      0.08      0.15      1000
#
#     accuracy                           0.54      2000
#    macro avg       0.72      0.54      0.42      2000
# weighted avg       0.72      0.54      0.42      2000
# n neighbors: 3
# metric: cityblock
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.83      0.06      0.11      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.67      0.52      0.39      2000
# weighted avg       0.67      0.52      0.39      2000
# n neighbors: 3
# metric: euclidean
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.52      0.99      0.68      1000
#        Relay       0.88      0.08      0.15      1000
#
#     accuracy                           0.53      2000
#    macro avg       0.70      0.53      0.41      2000
# weighted avg       0.70      0.53      0.41      2000
# n neighbors: 3
# metric: manhattan
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.83      0.06      0.11      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.67      0.52      0.39      2000
# weighted avg       0.67      0.52      0.39      2000
# n neighbors: 3
# metric: l2
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.52      0.99      0.68      1000
#        Relay       0.88      0.08      0.15      1000
#
#     accuracy                           0.53      2000
#    macro avg       0.70      0.53      0.41      2000
# weighted avg       0.70      0.53      0.41      2000
# n neighbors: 3
# metric: l1
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.83      0.06      0.11      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.67      0.52      0.39      2000
# weighted avg       0.67      0.52      0.39      2000
# n neighbors: 50
# metric: cityblock
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.52      1.00      0.68      1000
#        Relay       0.97      0.08      0.15      1000
#
#     accuracy                           0.54      2000
#    macro avg       0.74      0.54      0.42      2000
# weighted avg       0.74      0.54      0.42      2000
# n neighbors: 50
# metric: euclidean
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.52      0.99      0.68      1000
#        Relay       0.90      0.08      0.15      1000
#
#     accuracy                           0.54      2000
#    macro avg       0.71      0.54      0.42      2000
# weighted avg       0.71      0.54      0.42      2000
# n neighbors: 50
# metric: manhattan
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.52      1.00      0.68      1000
#        Relay       0.97      0.08      0.15      1000
#
#     accuracy                           0.54      2000
#    macro avg       0.74      0.54      0.42      2000
# weighted avg       0.74      0.54      0.42      2000
# n neighbors: 50
# metric: l2
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.52      0.99      0.68      1000
#        Relay       0.90      0.08      0.15      1000
#
#     accuracy                           0.54      2000
#    macro avg       0.71      0.54      0.42      2000
# weighted avg       0.71      0.54      0.42      2000
# n neighbors: 50
# metric: l1
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.52      1.00      0.68      1000
#        Relay       0.97      0.08      0.15      1000
#
#     accuracy                           0.54      2000
#    macro avg       0.74      0.54      0.42      2000
# weighted avg       0.74      0.54      0.42      2000
# n neighbors: 5
# metric: cityblock
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.68      1000
#        Relay       0.86      0.07      0.12      1000
#
#     accuracy                           0.53      2000
#    macro avg       0.69      0.53      0.40      2000
# weighted avg       0.69      0.53      0.40      2000
# n neighbors: 5
# metric: euclidean
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.52      0.99      0.68      1000
#        Relay       0.89      0.08      0.15      1000
#
#     accuracy                           0.54      2000
#    macro avg       0.70      0.54      0.41      2000
# weighted avg       0.70      0.54      0.41      2000
# n neighbors: 5
# metric: manhattan
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.68      1000
#        Relay       0.86      0.07      0.12      1000
#
#     accuracy                           0.53      2000
#    macro avg       0.69      0.53      0.40      2000
# weighted avg       0.69      0.53      0.40      2000
# n neighbors: 5
# metric: l2
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.52      0.99      0.68      1000
#        Relay       0.89      0.08      0.15      1000
#
#     accuracy                           0.54      2000
#    macro avg       0.70      0.54      0.41      2000
# weighted avg       0.70      0.54      0.41      2000
# n neighbors: 5
# metric: l1
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.68      1000
#        Relay       0.86      0.07      0.12      1000
#
#     accuracy                           0.53      2000
#    macro avg       0.69      0.53      0.40      2000
# weighted avg       0.69      0.53      0.40      2000

# %%
for n in {3,5,10,50}:
    for m in {"cityblock", "euclidean", "l1", "l2","manhattan"}:
        clf = KNN(contamination=0.01, n_neighbors=n, metric=m)
        clf.fit(X_train_scaled_standard)

        # pyod.predict: 0 = inlier, 1 = outlier
        y_pred = clf.predict(X_test_combined_scaled_standard)

        # cm und report
        cm = confusion_matrix(y_true, y_pred, labels=[1,0])
        print(f"n neighbors: {n}")
        print(f"metric: {m}")
        print("\nClassification Report:\n", classification_report(y_true, y_pred, target_names=["Normal","Relay"]))

        # plot
        plt.figure(figsize=(6,5))
        sns.heatmap(cm, annot=True, fmt="d",
                    xticklabels=["Relay","Normal"],
                    yticklabels=["Relay","Normal"],
                    cbar=False)
        plt.xlabel("Predicted")
        plt.ylabel("True")
        plt.title("Konfusionsmatrix")
        plt.tight_layout()
        plt.show()
# Out:
# n neighbors: 10
# metric: cityblock
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.88      0.04      0.07      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.69      0.52      0.37      2000
# weighted avg       0.69      0.52      0.37      2000
# n neighbors: 10
# metric: euclidean
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.86      0.04      0.07      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.68      0.52      0.37      2000
# weighted avg       0.68      0.52      0.37      2000
# n neighbors: 10
# metric: manhattan
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.88      0.04      0.07      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.69      0.52      0.37      2000
# weighted avg       0.69      0.52      0.37      2000
# n neighbors: 10
# metric: l2
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.86      0.04      0.07      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.68      0.52      0.37      2000
# weighted avg       0.68      0.52      0.37      2000
# n neighbors: 10
# metric: l1
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.88      0.04      0.07      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.69      0.52      0.37      2000
# weighted avg       0.69      0.52      0.37      2000
# n neighbors: 3
# metric: cityblock
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.83      0.04      0.07      1000
#
#     accuracy                           0.51      2000
#    macro avg       0.67      0.51      0.37      2000
# weighted avg       0.67      0.51      0.37      2000
# n neighbors: 3
# metric: euclidean
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.82      0.03      0.06      1000
#
#     accuracy                           0.51      2000
#    macro avg       0.67      0.51      0.37      2000
# weighted avg       0.67      0.51      0.37      2000
# n neighbors: 3
# metric: manhattan
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.83      0.04      0.07      1000
#
#     accuracy                           0.51      2000
#    macro avg       0.67      0.51      0.37      2000
# weighted avg       0.67      0.51      0.37      2000
# n neighbors: 3
# metric: l2
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.82      0.03      0.06      1000
#
#     accuracy                           0.51      2000
#    macro avg       0.67      0.51      0.37      2000
# weighted avg       0.67      0.51      0.37      2000
# n neighbors: 3
# metric: l1
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.83      0.04      0.07      1000
#
#     accuracy                           0.51      2000
#    macro avg       0.67      0.51      0.37      2000
# weighted avg       0.67      0.51      0.37      2000
# n neighbors: 50
# metric: cityblock
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.89      0.04      0.08      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.70      0.52      0.37      2000
# weighted avg       0.70      0.52      0.37      2000
# n neighbors: 50
# metric: euclidean
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      1.00      0.67      1000
#        Relay       0.91      0.04      0.08      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.71      0.52      0.38      2000
# weighted avg       0.71      0.52      0.38      2000
# n neighbors: 50
# metric: manhattan
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.89      0.04      0.08      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.70      0.52      0.37      2000
# weighted avg       0.70      0.52      0.37      2000
# n neighbors: 50
# metric: l2
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      1.00      0.67      1000
#        Relay       0.91      0.04      0.08      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.71      0.52      0.38      2000
# weighted avg       0.71      0.52      0.38      2000
# n neighbors: 50
# metric: l1
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.89      0.04      0.08      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.70      0.52      0.37      2000
# weighted avg       0.70      0.52      0.37      2000
# n neighbors: 5
# metric: cityblock
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.86      0.04      0.07      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.69      0.52      0.37      2000
# weighted avg       0.69      0.52      0.37      2000
# n neighbors: 5
# metric: euclidean
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.88      0.04      0.07      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.70      0.52      0.37      2000
# weighted avg       0.70      0.52      0.37      2000
# n neighbors: 5
# metric: manhattan
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.86      0.04      0.07      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.69      0.52      0.37      2000
# weighted avg       0.69      0.52      0.37      2000
# n neighbors: 5
# metric: l2
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.88      0.04      0.07      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.70      0.52      0.37      2000
# weighted avg       0.70      0.52      0.37      2000
# n neighbors: 5
# metric: l1
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.86      0.04      0.07      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.69      0.52      0.37      2000
# weighted avg       0.69      0.52      0.37      2000

# %%
for n in {3,5,10,50}:
    for m in {"cityblock", "euclidean", "l1", "l2","manhattan"}:
        clf = KNN(contamination=0.01, n_neighbors=n, metric=m)
        clf.fit(X_train_scaled_minmax)

        # pyod.predict: 0 = inlier, 1 = outlier
        y_pred = clf.predict(X_test_combined_scaled_minmax)

        # cm und report
        cm = confusion_matrix(y_true, y_pred, labels=[1,0])
        print(f"n neighbors: {n}")
        print(f"metric: {m}")
        print("\nClassification Report:\n", classification_report(y_true, y_pred, target_names=["Normal","Relay"]))

        # plot
        plt.figure(figsize=(6,5))
        sns.heatmap(cm, annot=True, fmt="d",
                    xticklabels=["Relay","Normal"],
                    yticklabels=["Relay","Normal"],
                    cbar=False)
        plt.xlabel("Predicted")
        plt.ylabel("True")
        plt.title("Konfusionsmatrix")
        plt.tight_layout()
        plt.show()
# Out:
# n neighbors: 10
# metric: cityblock
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.90      0.05      0.09      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.71      0.52      0.38      2000
# weighted avg       0.71      0.52      0.38      2000
# n neighbors: 10
# metric: euclidean
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.87      0.05      0.09      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.69      0.52      0.38      2000
# weighted avg       0.69      0.52      0.38      2000
# n neighbors: 10
# metric: manhattan
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.90      0.05      0.09      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.71      0.52      0.38      2000
# weighted avg       0.71      0.52      0.38      2000
# n neighbors: 10
# metric: l2
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.87      0.05      0.09      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.69      0.52      0.38      2000
# weighted avg       0.69      0.52      0.38      2000
# n neighbors: 10
# metric: l1
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.90      0.05      0.09      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.71      0.52      0.38      2000
# weighted avg       0.71      0.52      0.38      2000
# n neighbors: 3
# metric: cityblock
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.80      0.04      0.07      1000
#
#     accuracy                           0.51      2000
#    macro avg       0.65      0.51      0.37      2000
# weighted avg       0.65      0.51      0.37      2000
# n neighbors: 3
# metric: euclidean
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.84      0.04      0.07      1000
#
#     accuracy                           0.51      2000
#    macro avg       0.67      0.51      0.37      2000
# weighted avg       0.67      0.51      0.37      2000
# n neighbors: 3
# metric: manhattan
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.80      0.04      0.07      1000
#
#     accuracy                           0.51      2000
#    macro avg       0.65      0.51      0.37      2000
# weighted avg       0.65      0.51      0.37      2000
# n neighbors: 3
# metric: l2
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.84      0.04      0.07      1000
#
#     accuracy                           0.51      2000
#    macro avg       0.67      0.51      0.37      2000
# weighted avg       0.67      0.51      0.37      2000
# n neighbors: 3
# metric: l1
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.80      0.04      0.07      1000
#
#     accuracy                           0.51      2000
#    macro avg       0.65      0.51      0.37      2000
# weighted avg       0.65      0.51      0.37      2000
# n neighbors: 50
# metric: cityblock
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      1.00      0.67      1000
#        Relay       0.91      0.04      0.07      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.71      0.52      0.37      2000
# weighted avg       0.71      0.52      0.37      2000
# n neighbors: 50
# metric: euclidean
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.89      0.04      0.08      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.70      0.52      0.37      2000
# weighted avg       0.70      0.52      0.37      2000
# n neighbors: 50
# metric: manhattan
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      1.00      0.67      1000
#        Relay       0.91      0.04      0.07      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.71      0.52      0.37      2000
# weighted avg       0.71      0.52      0.37      2000
# n neighbors: 50
# metric: l2
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.89      0.04      0.08      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.70      0.52      0.37      2000
# weighted avg       0.70      0.52      0.37      2000
# n neighbors: 50
# metric: l1
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      1.00      0.67      1000
#        Relay       0.91      0.04      0.07      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.71      0.52      0.37      2000
# weighted avg       0.71      0.52      0.37      2000
# n neighbors: 5
# metric: cityblock
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.82      0.04      0.07      1000
#
#     accuracy                           0.51      2000
#    macro avg       0.66      0.51      0.37      2000
# weighted avg       0.66      0.51      0.37      2000
# n neighbors: 5
# metric: euclidean
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.84      0.04      0.07      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.67      0.52      0.37      2000
# weighted avg       0.67      0.52      0.37      2000
# n neighbors: 5
# metric: manhattan
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.82      0.04      0.07      1000
#
#     accuracy                           0.51      2000
#    macro avg       0.66      0.51      0.37      2000
# weighted avg       0.66      0.51      0.37      2000
# n neighbors: 5
# metric: l2
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.84      0.04      0.07      1000
#
#     accuracy                           0.52      2000
#    macro avg       0.67      0.52      0.37      2000
# weighted avg       0.67      0.52      0.37      2000
# n neighbors: 5
# metric: l1
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.51      0.99      0.67      1000
#        Relay       0.82      0.04      0.07      1000
#
#     accuracy                           0.51      2000
#    macro avg       0.66      0.51      0.37      2000
# weighted avg       0.66      0.51      0.37      2000
